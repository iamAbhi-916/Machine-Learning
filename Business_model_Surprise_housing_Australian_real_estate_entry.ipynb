# %%
import pandas as pd 
df = pd.read_csv('C:/Users/user/Desktop/train.csv')

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df = df.drop(['PoolQC', 'Fence','MiscFeature','Alley'],axis =1 )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# # remove null values.

# %%
df[['LotFrontage']] = df[['LotFrontage']].fillna(df['LotFrontage'].mean())

# %%
df[['MasVnrType']] = df[['MasVnrType']].fillna(df['MasVnrType'].mode()[0])

# %%
df[['MasVnrArea']] = df[['MasVnrArea']].fillna(df['MasVnrArea'].mean())

# %%
df[['BsmtQual']] = df[['BsmtQual']].fillna(df['BsmtQual'].mode()[0])
df[['BsmtCond']] = df[['BsmtCond']].fillna(df['BsmtCond'].mode()[0])
df[['BsmtExposure']] = df[['BsmtExposure']].fillna(df['BsmtExposure'].mode()[0])
df[['BsmtFinType1']] = df[['BsmtFinType1']].fillna(df['BsmtFinType1'].mode()[0])
df[['BsmtFinType2']] = df[['BsmtFinType2']].fillna(df['BsmtFinType2'].mode()[0])
df[['BsmtFinSF2']] = df[['BsmtFinSF2']].fillna(df['BsmtFinSF2'].mean())

# %%
df[['Electrical']] = df[['Electrical']].fillna(df['Electrical'].mode()[0])

# %%
df[['FireplaceQu']] = df[['FireplaceQu']].fillna(df['FireplaceQu'].mode()[0])

# %%
df[['GarageType']] = df[['GarageType']].fillna(df['GarageType'].mode()[0])
df[['GarageYrBlt']] = df[['GarageYrBlt']].fillna(df['GarageYrBlt'].mean())
df[['GarageFinish']] = df[['GarageFinish']].fillna(df['GarageFinish'].mode()[0])
df[['GarageQual']] = df[['GarageQual']].fillna(df['GarageQual'].mode()[0])
df[['GarageCond']] = df[['GarageCond']].fillna(df['GarageCond'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
len(df['SaleCondition'].unique())
# Out:
# 6

# %% [markdown]
# # encoding categorical features .

# %%
mszoning = df.MSZoning.value_counts().to_dict()
street = df.Street.value_counts().to_dict()
LotShape= df.LotShape.value_counts().to_dict()
LandContour = df.LandContour.value_counts().to_dict()
Utilities = df.Utilities.value_counts().to_dict()
LotConfig = df.LotConfig.value_counts().to_dict()
LandSlope = df.LandSlope.value_counts().to_dict()
Neighborhood = df.Neighborhood.value_counts().to_dict()
Condition1 = df.Condition1.value_counts().to_dict()
Condition2 = df.Condition2.value_counts().to_dict()
BldgType = df.BldgType.value_counts().to_dict()
HouseStyle = df.HouseStyle.value_counts().to_dict()
RoofStyle = df.RoofStyle.value_counts().to_dict()
RoofMatl = df.RoofMatl.value_counts().to_dict()
Exterior1st = df.Exterior1st.value_counts().to_dict()
Exterior2nd = df.Exterior2nd.value_counts().to_dict()
MasVnrType= df.MasVnrType.value_counts().to_dict()
ExterQual = df.ExterQual.value_counts().to_dict()
ExterCond = df.ExterCond.value_counts().to_dict()
Foundation = df.MSZoning.value_counts().to_dict()
BsmtQual = df.BsmtQual.value_counts().to_dict()
BsmtCond = df.BsmtCond.value_counts().to_dict()
BsmtExposure  = df.BsmtExposure.value_counts().to_dict()
BsmtFinType1 = df.BsmtFinType1.value_counts().to_dict()
BsmtFinType2 = df.BsmtFinType2.value_counts().to_dict()
Heating = df.Heating.value_counts().to_dict()
HeatingQC = df.HeatingQC.value_counts().to_dict()
CentralAir = df.CentralAir.value_counts().to_dict()
Electrical = df.Electrical.value_counts().to_dict()
KitchenQual = df.KitchenQual.value_counts().to_dict()
Functional = df.Functional.value_counts().to_dict()
FireplaceQu = df.FireplaceQu.value_counts().to_dict()
GarageType = df.GarageType.value_counts().to_dict()
GarageFinish = df.GarageFinish.value_counts().to_dict()
PavedDrive = df.PavedDrive.value_counts().to_dict()
GarageCond = df.GarageCond.value_counts().to_dict()
GarageQual = df.GarageQual.value_counts().to_dict()
SaleType = df.SaleType.value_counts().to_dict()
SaleCondition = df.SaleCondition.value_counts().to_dict()
Foundation = df.Foundation.value_counts().to_dict() 
print(mszoning)
print(SaleType)
# Out:
# {'RL': 1151, 'RM': 218, 'FV': 65, 'RH': 16, 'C (all)': 10}
# {'WD': 1267, 'New': 122, 'COD': 43, 'ConLD': 9, 'ConLw': 5, 'ConLI': 5, 'CWD': 4, 'Oth': 3, 'Con': 2}

# %%
df.MSZoning = df.MSZoning.map(mszoning)
df.Street = df.Street.map(street)
df.LotShape = df.LotShape.map(LotShape)
df.LandContour = df.LandContour.map(LandContour)
df.Utilities = df.Utilities.map(Utilities)
df.LotConfig = df.LotConfig.map(LotConfig)
df.LandSlope = df.LandSlope.map(LandSlope)
df.Neighborhood = df.Neighborhood.map(Neighborhood)
df.Condition1 = df.Condition1.map(Condition1)
df.Condition2 = df.Condition2.map(Condition2)
df.BldgType = df.BldgType.map(BldgType)
df.HouseStyle = df.HouseStyle.map(HouseStyle)
df.RoofStyle = df.RoofStyle.map(RoofStyle)
df.RoofMatl = df.RoofMatl.map(RoofMatl)
df.Exterior1st = df.Exterior1st.map(Exterior1st)
df.Exterior2nd = df.Exterior2nd.map(Exterior2nd)
df.MasVnrType = df.MasVnrType.map(MasVnrType)
df.ExterQual = df.ExterQual.map(ExterQual)
df.ExterCond = df.ExterCond.map(ExterCond)
df.Foundation = df.Foundation.map(Foundation)
df.BsmtQual = df.BsmtQual.map(BsmtQual)
df.BsmtCond = df.BsmtCond.map(BsmtCond)
df.BsmtExposure = df.BsmtExposure.map(BsmtExposure)
df.BsmtFinType1 = df.BsmtFinType1.map(BsmtFinType1)
df.BsmtFinType2 = df.BsmtFinType2.map(BsmtFinType2)
df.HeatingQC = df.HeatingQC.map(HeatingQC)
df.Heating = df.Heating.map(Heating)
df.CentralAir = df.CentralAir.map(CentralAir)
df.Electrical = df.Electrical.map(Electrical)
df.KitchenQual = df.KitchenQual.map(KitchenQual)
df.Functional = df.Functional.map(Functional)
df.FireplaceQu = df.FireplaceQu.map(FireplaceQu)
df.GarageType = df.GarageType.map(GarageType)
df.GarageFinish = df.GarageFinish.map(GarageFinish)
df.PavedDrive = df.PavedDrive.map(PavedDrive)
df.GarageCond  = df.GarageCond.map(GarageCond)
df.GarageQual  = df.GarageQual.map(GarageQual)
df.SaleType = df.SaleType.map(SaleType)
df.SaleCondition = df.SaleCondition.map(SaleCondition)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   LotShape       1460 non-null   int64
#  7   LandContour    1460 non-null   int64
#  8   Utilities      1460 non-null   int64
#  9   LotConfig      1460 non-null   int64
#  10  LandSlope      1460 non-null   int64
#  11  Neighborhood   1460 non-null   int64
#  12  Condition1     1460 non-null   int64
#  13  Condition2     1460 non-null   int64
#  14  BldgType       1460 non-null   int64
#  15  HouseStyle     1460 non-null   int64
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
# ...

# %% [markdown]
# # feature selection

# %% [markdown]
# # univariate selection

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
x= df.drop('SalePrice' , axis =1 )
y = df['SalePrice']
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(20,'Score'))  #print 10 best features
# Out:
#             Specs         Score
# 4         LotArea  1.011497e+07
# 71        MiscVal  6.253332e+06
# 43       2ndFlrSF  4.648841e+05
# 33     BsmtFinSF1  3.999851e+05
# 70       PoolArea  3.835642e+05
# 35     BsmtFinSF2  3.688827e+05
# 25     MasVnrArea  2.857403e+05
# 36      BsmtUnfSF  2.747512e+05
# 44   LowQualFinSF  2.448810e+05
# 45      GrLivArea  1.968501e+05
# 37    TotalBsmtSF  1.747065e+05
# 31   BsmtExposure  1.559827e+05
# 68      3SsnPorch  1.549360e+05
# 0              Id  1.548417e+05
# 75  SaleCondition  1.487708e+05
# 69    ScreenPorch  1.366295e+05
# 65     WoodDeckSF  1.298338e+05
# 74       SaleType  1.297126e+05
# 42       1stFlrSF  1.238098e+05
# 2        MSZoning  1.231780e+05

# %% [markdown]
# # feature importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
#print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # above output shows the most important or relatable features to analyse the pricing of a house .(here only 20 most features are taken into consideration , via two methods : univariate selection , feature importance )

# %%
X_final = x[['LotArea','MiscVal',  '2ndFlrSF', 'BsmtFinSF1', 'PoolArea', 'BsmtFinSF2', 'MasVnrArea',  'BsmtUnfSF', 'LowQualFinSF', 'GrLivArea', 'TotalBsmtSF','BsmtExposure','3SsnPorch' , 'Neighborhood', 'SaleCondition' , 'ScreenPorch','WoodDeckSF', 'SaleType', '1stFlrSF','MSZoning']]

# %%
X_final.head()
# Out:
#    LotArea  MiscVal  2ndFlrSF  BsmtFinSF1  PoolArea  BsmtFinSF2  MasVnrArea  \
# 0     8450        0       854         706         0           0       196.0
# 1     9600        0         0         978         0           0         0.0
# 2    11250        0       866         486         0           0       162.0
# 3     9550        0       756         216         0           0         0.0
# 4    14260        0      1053         655         0           0       350.0
#
#    BsmtUnfSF  LowQualFinSF  GrLivArea  TotalBsmtSF  BsmtExposure  3SsnPorch  \
# 0        150             0       1710          856           991          0
# 1        284             0       1262         1262           134          0
# 2        434             0       1786          920           114          0
# 3        540             0       1717          756           991          0
# 4        490             0       2198         1145           221          0
#
# ...

# %% [markdown]
# # linear  Reggression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.3, random_state=0)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

lin_regressor=LinearRegression()
mse=cross_val_score(lin_regressor,X_train,y_train,scoring='neg_mean_squared_error',cv=5)
mean_mse=np.mean(mse)
print(mean_mse)
lin_regressor.fit(X_train , y_train)
lin_regressor.score(X_test, y_test)
# Out:
# -1748782308.492168
# 0.5742180555000074

# %% [markdown]
# # Ridge Regressor

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 100}
# -1748770579.7423623

# %% [markdown]
# # Lasso Regressor

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X_train,y_train)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 599580606524.7775, tolerance: 500724925.90235
#   positive)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 655558101176.84, tolerance: 485030198.0440296
#   positive)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 628915030340.9735, tolerance: 458893202.3544334
#   positive)
# ...

# %%
prediction_lasso=lasso_regressor.predict(X_test)
prediction_ridge=ridge_regressor.predict(X_test)

# %%
import seaborn as sns

sns.distplot(y_test-prediction_lasso)

# %%
import seaborn as sns

sns.distplot(y_test-prediction_ridge)

# %% [markdown]
# # lasso performs better here
